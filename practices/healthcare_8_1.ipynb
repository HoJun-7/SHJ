# %%
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/suninno/healthcare_bigdata_playbook_kr/refs/heads/main/ch08/OTg6QzA_activities.csv"
df = pd.read_csv(url, delimiter = ",")

# %%
df

# %%
df.shape

# %%
X = df.X.to_numpy()
Y = df.Y.to_numpy()

# %%
X

# %%
Y

# %%
plt.style.use('bmh')
plt.figure(facecolor = 'white')

plt.scatter(X, Y)
plt.show()

# %%
plt.figure(facecolor = 'white')
plt.hist2d(X, Y, bins = (25, 25), cmap = plt.cm.Reds)
cb = plt.colorbar()
cb.set_label('frequency of appearance, bins=25')

# %%
plt.figure(facecolor='white')
plt.hist2d(X, Y, bins = (40, 40), cmap = plt.cm.Greens)
cb = plt.colorbar()
cb.set_label('frequency of appearance, bins=40')

# %%
plt.figure(facecolor = 'white')
plt.hexbin(X, Y, gridsize = 20, cmap = plt.cm.Blues)
cb = plt.colorbar()
cb.set_label('frequency of appearance, gridsize=20')

# %%
x1 = X[:16570] # 0 ~ 16569 x값
x2 = X[16570:16570*2] # 16570 ~ 33139 x값
x3 = X[16570*2:16570*3] # 33140 ~ 49709 x값
x4 = X[16570*3:] # 49710 ~ 66279 x값

y1 = Y[:16570] # 0 ~ 16569 y값
y2 = Y[16570:16570*2] # 16570 ~ 33139 y값
y3 = Y[16570*2:16570*3] # 33140 ~ 49709 y값
y4 = Y[16570*3:] # 49710 ~ 66279 y값

# %%
plt.figure(facecolor='white')

# 1-Q(1등분)
plt.subplot(2, 2, 1)
plt.hist2d(x1, y1, bins = 20, cmap = plt.cm.inferno)
plt.title('1-Q')
plt.colorbar()

# 2-Q(2등분)
plt.subplot(2, 2, 2)
plt.hist2d(x2, y2, bins = 20, cmap = plt.cm.plasma)
plt.title('2-Q')
plt.colorbar()

# 3-Q(3등분)
plt.subplot(2, 2, 3)
plt.hist2d(x3, y3, bins = 20, cmap = plt.cm.magma)
plt.title('3-Q')
plt.colorbar()

# 4-Q(4등분)
plt.subplot(2, 2, 4)
plt.hist2d(x4, y4, bins = 20, cmap = plt.cm.cividis)
plt.title('4-Q')
plt.colorbar()

plt.show()

# %%
Z = df.Z.to_numpy()

# %%
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(111, projection = '3d')

# 산점도 (scatter plot)
ax.scatter(X, Y, Z, c = Z, cmap = 'viridis', marker = 'o')

# 축 레이블 설정
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
ax.set_title('3D Scatter Plot')

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/GitHub/SHJ/practices

# %%
pwd

# %%
# !git clone https://HoJun-7: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@github.com/HoJun-7/SHJ.git
